# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys

# 파이썬 인터프리터에게 모듈을 아래 경로에서 찾으라고 알림
sys.path.append('/content/drive/MyDrive/001 Work/001_02 실습조교_패스트캠퍼스B2B/220516_교보생명/강의자료')

# %%
import a
# import a as kkkkk

print(a.data)
a.func(100)
# Out:
# [10, 20, 30]
# 130.0

# %%
type(a)
# Out:
# module

# %%
객체 = a.수업시간()

# %%
from a import data, func
# from a import *

func(1000)
# Out:
# 1300.0

# %%
# import 모듈명
# import 모듈명 as 다른이름
# from 모듈명 import 함수, 클래스, 데이터

# %%
import pandas 
import pandas as pd
from pandas import DataFrame 

pandas.DataFrame()
pd.DataFrame()
DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # 파이썬 모듈

# %% [markdown]
# 함수/클래스/변수를 한데 모아 `정리` 해 놓은 것을 모듈이라고 합니다. 누군가에게 함수나 클래스 단위로 코드를 공유한다면 어떨까요? 빈번하게 배포해야하며, 코드를 유지 관리하기가 어렵습니다.

# %% [markdown]
# 파이썬의 모듈은 파일 단위로 함수/클래스/변수를 관리합니다.

# %% [markdown]
# - 함께 실습해 봅시다.

# %% [markdown]
# ----

# %% [markdown]
# # 파이썬 패키지

# %% [markdown]
# 복잡한 구현 및 관련 있는 여러 개의 파일을 한 데 묶어서 정리할 수도 있습니다. 이를 패키지라고 합니다. 폴더 안에 관련 있는 여러 개의 파이썬 파일(`.py`)을 묶어 놓은 겁니다.

# %% [markdown]
# 예를 들어 `스크래핑` 패키지라면 다음과 같이 여러개의 분야 정보를 한데 묶어 정리해 놓을 수 있습니다.

# %% [markdown]
# 스크래핑
# > 유가증권.py
# > 암호화폐.py

# %% [markdown]
# 더욱 더 많은 기능을 지원한다면 다시 폴더 구조로 세밀하게 정리할 수도 있습니다.

# %%
# import 스크래핑.유가증권.stock as s

# %% [markdown]
# 스크래핑
# > 유가증권
# >> stock.py
# >> etf.py
#
# > 암호화폐
# >> bithumb.py
# >> upbit.py

# %% [markdown]
# ## 모듈 탐색 순서
# 1. 코드가 저장된 위치 탐색
# 2. 파이썬 설치 경로 탐색

# %% [markdown]
# 아나콘다와 함께 설치된 다양한 모듈과 패키지

# %% [markdown]
# <img src="https://i.ibb.co/nckC2Ty/image.png" width="400" style="float:left" />

# %%
import matplotlib.pyplot as plt

# matplotlib.pyplot.plot([1,2,4],[4,8,2]) 지금 이거는 에러나지 plt라고 하기로 했으니까
plt.plot([1,2,4],[4,8,2])

# %%
import datetime

print(datetime.datetime.now())
datetime.datetime.now()
# Out:
# 2022-05-17 06:44:28.816852
# datetime.datetime(2022, 5, 17, 6, 44, 28, 816977)

# %%
a = datetime.datetime.now()
a.day
# Out:
# 17
